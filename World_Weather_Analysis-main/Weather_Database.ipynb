# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module.
cities = []

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# %%
#Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=441aa9a01fdf53c411df6287cb0e1c23

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# base url 
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | kapaa
# Processing Record 2 of the Set 1 | upernavik
# Processing Record 3 of the Set 1 | busselton
# Processing Record 4 of the Set 1 | castro
# Processing Record 5 of the Set 1 | puerto ayora
# Processing Record 6 of the Set 1 | nagato
# Processing Record 7 of the Set 1 | cape town
# Processing Record 8 of the Set 1 | cidreira
# Processing Record 9 of the Set 1 | east london
# Processing Record 10 of the Set 1 | georgetown
# Processing Record 11 of the Set 1 | bilma
# Processing Record 12 of the Set 1 | ponta do sol
# Processing Record 13 of the Set 1 | fortuna
# Processing Record 14 of the Set 1 | hervey bay
# Processing Record 15 of the Set 1 | huarmey
# Processing Record 16 of the Set 1 | grindavik
# Processing Record 17 of the Set 1 | larsnes
# Processing Record 18 of the Set 1 | bluff
# Processing Record 19 of the Set 1 | kodiak
# Processing Record 20 of the Set 1 | awjilah
# Processing Record 21 of the Set 1 | nhulunbuy
# Processing Record 22 of the Set 1 | cochrane
# Processing Record 23 of the Set 1 | barentsburg
# Processing Record 24 of the Set 1 | omsukchan
# Processing Record 25 of the Set 1 | barrow
# Processing Record 26 of the Set 1 | mataura
# Processing Record 27 of the Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of the Set 1 | amuntai
# Processing Record 29 of the Set 1 | hobart
# Processing Record 30 of the Set 1 | meyungs
# Processing Record 31 of the Set 1 | kyren
# Processing Record 32 of the Set 1 | mtsensk
# Processing Record 33 of the Set 1 | praia da vitoria
# Processing Record 34 of the Set 1 | tuktoyaktuk
# Processing Record 35 of the Set 1 | zhangye
# Processing Record 36 of the Set 1 | handwara
# Processing Record 37 of the Set 1 | quatre cocos
# Processing Record 38 of the Set 1 | matay
# Processing Record 39 of the Set 1 | antonina
# Processing Record 40 of the Set 1 | yellowknife
# Processing Record 41 of the Set 1 | saint george
# Processing Record 42 of the Set 1 | ronneby
# Processing Record 43 of the Set 1 | luderitz
# Processing Record 44 of the Set 1 | new norfolk
# Processing Record 45 of the Set 1 | coquimbo
# Processing Record 46 of the Set 1 | mariakani
# Processing Record 47 of the Set 1 | thompson
# Processing Record 48 of the Set 1 | narsaq
# Processing Record 49 of the Set 1 | morag
# Processing Record 50 of the Set 1 | kaitangata
# Processing Record 1 of the Set 2 | hilo
# Processing Record 2 of the Set 2 | itarema
# Processing Record 3 of the Set 2 | kahului
# Processing Record 4 of the Set 2 | saint anthony
# Processing Record 5 of the Set 2 | fairbanks
# Processing Record 6 of the Set 2 | butaritari
# Processing Record 7 of the Set 2 | jamestown
# Processing Record 8 of the Set 2 | suhum
# Processing Record 9 of the Set 2 | hare bay
# Processing Record 10 of the Set 2 | chuy
# Processing Record 11 of the Set 2 | porto novo
# Processing Record 12 of the Set 2 | atuona
# Processing Record 13 of the Set 2 | rikitea
# Processing Record 14 of the Set 2 | shellbrook
# Processing Record 15 of the Set 2 | marcona
# Processing Record 16 of the Set 2 | hudson bay
# Processing Record 17 of the Set 2 | ushuaia
# Processing Record 18 of the Set 2 | morros
# Processing Record 19 of the Set 2 | san quintin
# Processing Record 20 of the Set 2 | nizhneyansk
# Processing Record 21 of the Set 2 | port alfred
# Processing Record 22 of the Set 2 | pacific grove
# Processing Record 23 of the Set 2 | hobyo
# Processing Record 24 of the Set 2 | eskasem
# Processing Record 25 of the Set 2 | tasiilaq
# Processing Record 26 of the Set 2 | hermanus
# Processing Record 27 of the Set 2 | qinhuangdao
# Processing Record 28 of the Set 2 | samana
# Processing Record 29 of the Set 2 | baykit
# Processing Record 30 of the Set 2 | albany
# Processing Record 31 of the Set 2 | qaanaaq
# Processing Record 32 of the Set 2 | richards bay
# Processing Record 33 of the Set 2 | torbay
# Processing Record 34 of the Set 2 | coihaique
# Processing Record 35 of the Set 2 | college
# Processing Record 36 of the Set 2 | ambodifototra
# Processing Record 37 of the Set 2 | ostrovnoy
# Processing Record 38 of the Set 2 | banda aceh
# Processing Record 39 of the Set 2 | tiksi
# Processing Record 40 of the Set 2 | caravelas
# Processing Record 41 of the Set 2 | port elizabeth
# Processing Record 42 of the Set 2 | ribeira grande
# Processing Record 43 of the Set 2 | fukue
# Processing Record 44 of the Set 2 | cabedelo
# Processing Record 45 of the Set 2 | mugur-aksy
# Processing Record 46 of the Set 2 | kansanshi
# Processing Record 47 of the Set 2 | mar del plata
# Processing Record 48 of the Set 2 | san andres
# Processing Record 49 of the Set 2 | illoqqortoormiut
# Processing Record 50 of the Set 2 | bassano
# Processing Record 1 of the Set 3 | skagastrond
# Processing Record 2 of the Set 3 | stornoway
# Processing Record 3 of the Set 3 | dicabisagan
# Processing Record 4 of the Set 3 | campbellsville
# Processing Record 5 of the Set 3 | allahganj
# Processing Record 6 of the Set 3 | kabare
# Processing Record 7 of the Set 3 | poum
# Processing Record 8 of the Set 3 | avarua
# Processing Record 9 of the Set 3 | san juan
# Processing Record 10 of the Set 3 | bengkulu
# Processing Record 11 of the Set 3 | hermosillo
# Processing Record 12 of the Set 3 | cayenne
# Processing Record 13 of the Set 3 | grand river south east
# Processing Record 14 of the Set 3 | pudem
# Processing Record 15 of the Set 3 | laukaa
# Processing Record 16 of the Set 3 | homer
# Processing Record 17 of the Set 3 | partenit
# Processing Record 18 of the Set 3 | labuhan
# Processing Record 19 of the Set 3 | kerki
# Processing Record 20 of the Set 3 | gari
# Processing Record 21 of the Set 3 | hellvik
# Processing Record 22 of the Set 3 | hithadhoo
# Processing Record 23 of the Set 3 | padang
# Processing Record 24 of the Set 3 | victoria
# Processing Record 25 of the Set 3 | san jeronimo
# Processing Record 26 of the Set 3 | attawapiskat
# Processing Record 27 of the Set 3 | san pedro
# Processing Record 28 of the Set 3 | sola
# Processing Record 29 of the Set 3 | buala
# Processing Record 30 of the Set 3 | klaksvik
# Processing Record 31 of the Set 3 | balclutha
# Processing Record 32 of the Set 3 | lebu
# Processing Record 33 of the Set 3 | amderma
# Processing Record 34 of the Set 3 | kapustin yar-1
# Processing Record 35 of the Set 3 | williams lake
# Processing Record 36 of the Set 3 | rio gallegos
# Processing Record 37 of the Set 3 | mys shmidta
# Processing Record 38 of the Set 3 | guilin
# Processing Record 39 of the Set 3 | paine
# Processing Record 40 of the Set 3 | ouadda
# Processing Record 41 of the Set 3 | hambantota
# Processing Record 42 of the Set 3 | punta arenas
# Processing Record 43 of the Set 3 | san ignacio
# Processing Record 44 of the Set 3 | lolua
# Processing Record 45 of the Set 3 | tomatlan
# Processing Record 46 of the Set 3 | omboue
# Processing Record 47 of the Set 3 | vanavara
# Processing Record 48 of the Set 3 | valdivia
# Processing Record 49 of the Set 3 | andenes
# Processing Record 50 of the Set 3 | vaini
# Processing Record 1 of the Set 4 | la romana
# Processing Record 2 of the Set 4 | kidal
# Processing Record 3 of the Set 4 | belmonte
# Processing Record 4 of the Set 4 | aripuana
# Processing Record 5 of the Set 4 | arraial do cabo
# Processing Record 6 of the Set 4 | chimore
# Processing Record 7 of the Set 4 | ancud
# Processing Record 8 of the Set 4 | bubaque
# Processing Record 9 of the Set 4 | koungou
# Processing Record 10 of the Set 4 | palmer
# Processing Record 11 of the Set 4 | shirokiy
# Processing Record 12 of the Set 4 | saint-philippe
# Processing Record 13 of the Set 4 | uhlove
# Processing Record 14 of the Set 4 | portobelo
# Processing Record 15 of the Set 4 | wakkanai
# Processing Record 16 of the Set 4 | bambous virieux
# Processing Record 17 of the Set 4 | inuvik
# Processing Record 18 of the Set 4 | bad neustadt
# Processing Record 19 of the Set 4 | avera
# Processing Record 20 of the Set 4 | mackay
# Processing Record 21 of the Set 4 | acarau
# Processing Record 22 of the Set 4 | cabo san lucas
# Processing Record 23 of the Set 4 | ponta delgada
# Processing Record 24 of the Set 4 | cockburn town
# Processing Record 25 of the Set 4 | dourbali
# Processing Record 26 of the Set 4 | tanete
# Processing Record 27 of the Set 4 | kodino
# Processing Record 28 of the Set 4 | tsihombe
# Processing Record 29 of the Set 4 | taolanaro
# Processing Record 30 of the Set 4 | provideniya
# Processing Record 31 of the Set 4 | makushino
# Processing Record 32 of the Set 4 | juneau
# Processing Record 33 of the Set 4 | flin flon
# Processing Record 34 of the Set 4 | constitucion
# Processing Record 35 of the Set 4 | dali
# Processing Record 36 of the Set 4 | samarai
# Processing Record 37 of the Set 4 | yulara
# Processing Record 38 of the Set 4 | pangoa
# Processing Record 39 of the Set 4 | katubao
# Processing Record 40 of the Set 4 | dikson
# Processing Record 41 of the Set 4 | auki
# Processing Record 42 of the Set 4 | pangnirtung
# Processing Record 43 of the Set 4 | isangel
# Processing Record 44 of the Set 4 | penzance
# Processing Record 45 of the Set 4 | marawi
# Processing Record 46 of the Set 4 | eldama ravine
# Processing Record 47 of the Set 4 | amahai
# Processing Record 48 of the Set 4 | lompoc
# Processing Record 49 of the Set 4 | alofi
# Processing Record 50 of the Set 4 | opelousas
# Processing Record 1 of the Set 5 | kantyshevo
# Processing Record 2 of the Set 5 | mayo
# Processing Record 3 of the Set 5 | goderich
# Processing Record 4 of the Set 5 | road town
# Processing Record 5 of the Set 5 | carnarvon
# Processing Record 6 of the Set 5 | katsuura
# Processing Record 7 of the Set 5 | kampene
# Processing Record 8 of the Set 5 | cherskiy
# Processing Record 9 of the Set 5 | harwich
# Processing Record 10 of the Set 5 | adjumani
# Processing Record 11 of the Set 5 | palenque
# Processing Record 12 of the Set 5 | amazar
# Processing Record 13 of the Set 5 | kaeo
# Processing Record 14 of the Set 5 | kalmunai
# Processing Record 15 of the Set 5 | bilibino
# Processing Record 16 of the Set 5 | karaton
# Processing Record 17 of the Set 5 | qui nhon
# Processing Record 18 of the Set 5 | riyadh
# Processing Record 19 of the Set 5 | kavieng
# Processing Record 20 of the Set 5 | geraldton
# Processing Record 21 of the Set 5 | namibe
# Processing Record 22 of the Set 5 | sitka
# Processing Record 23 of the Set 5 | killybegs
# Processing Record 24 of the Set 5 | villamartin
# Processing Record 25 of the Set 5 | salalah
# Processing Record 26 of the Set 5 | belushya guba
# Processing Record 27 of the Set 5 | esperance
# Processing Record 28 of the Set 5 | henderson
# Processing Record 29 of the Set 5 | pilani
# Processing Record 30 of the Set 5 | san patricio
# Processing Record 31 of the Set 5 | tapaua
# Processing Record 32 of the Set 5 | margate
# Processing Record 33 of the Set 5 | longyearbyen
# Processing Record 34 of the Set 5 | muros
# Processing Record 35 of the Set 5 | yar-sale
# Processing Record 36 of the Set 5 | sancraieni
# Processing Record 37 of the Set 5 | alenquer
# Processing Record 38 of the Set 5 | flinders
# Processing Record 39 of the Set 5 | voznesenye
# Processing Record 40 of the Set 5 | vysokogornyy
# Processing Record 41 of the Set 5 | alice springs
# Processing Record 42 of the Set 5 | paragould
# Processing Record 43 of the Set 5 | andros town
# Processing Record 44 of the Set 5 | xining
# Processing Record 45 of the Set 5 | berlevag
# Processing Record 46 of the Set 5 | huilong
# Processing Record 47 of the Set 5 | conde
# Processing Record 48 of the Set 5 | jiangyou
# Processing Record 49 of the Set 5 | codrington
# Processing Record 50 of the Set 5 | banihal
# Processing Record 1 of the Set 6 | missoula
# Processing Record 2 of the Set 6 | nanakuli
# Processing Record 3 of the Set 6 | kapit
# Processing Record 4 of the Set 6 | husavik
# Processing Record 5 of the Set 6 | nazarovo
# Processing Record 6 of the Set 6 | porto walter
# Processing Record 7 of the Set 6 | floro
# Processing Record 8 of the Set 6 | mahebourg
# Processing Record 9 of the Set 6 | trinidad
# Processing Record 10 of the Set 6 | mnogovershinnyy
# Processing Record 11 of the Set 6 | lagoa
# Processing Record 12 of the Set 6 | pisco
# Processing Record 13 of the Set 6 | egvekinot
# Processing Record 14 of the Set 6 | saskylakh
# Processing Record 15 of the Set 6 | lavrentiya
# Processing Record 16 of the Set 6 | santiago
# Processing Record 17 of the Set 6 | camacha
# Processing Record 18 of the Set 6 | chapais
# Processing Record 19 of the Set 6 | tumannyy
# Processing Record 20 of the Set 6 | bredasdorp
# Processing Record 21 of the Set 6 | nikolskoye
# Processing Record 22 of the Set 6 | puerto del rosario
# Processing Record 23 of the Set 6 | manakara
# Processing Record 24 of the Set 6 | inhambane
# Processing Record 25 of the Set 6 | sebinkarahisar
# Processing Record 26 of the Set 6 | bahia honda
# Processing Record 27 of the Set 6 | geretsried
# Processing Record 28 of the Set 6 | sao joao da barra
# Processing Record 29 of the Set 6 | ambikapur
# Processing Record 30 of the Set 6 | galgani
# Processing Record 31 of the Set 6 | huazolotitlan
# Processing Record 32 of the Set 6 | bakchar
# Processing Record 33 of the Set 6 | mecca
# Processing Record 34 of the Set 6 | akhnur
# Processing Record 35 of the Set 6 | zemaiciu naumiestis
# Processing Record 36 of the Set 6 | yuanping
# Processing Record 37 of the Set 6 | ilulissat
# Processing Record 38 of the Set 6 | olafsvik
# Processing Record 39 of the Set 6 | taksimo
# Processing Record 40 of the Set 6 | sipe sipe
# Processing Record 41 of the Set 6 | kuragino
# Processing Record 42 of the Set 6 | la primavera
# Processing Record 43 of the Set 6 | parana
# Processing Record 44 of the Set 6 | zlatoustovsk
# Processing Record 45 of the Set 6 | henties bay
# Processing Record 46 of the Set 6 | leningradskiy
# Processing Record 47 of the Set 6 | bellavista
# Processing Record 48 of the Set 6 | vao
# Processing Record 49 of the Set 6 | turmalina
# Processing Record 50 of the Set 6 | koboko
# Processing Record 1 of the Set 7 | buraydah
# Processing Record 2 of the Set 7 | chaihe
# Processing Record 3 of the Set 7 | sisimiut
# Processing Record 4 of the Set 7 | dingle
# Processing Record 5 of the Set 7 | presidencia roque saenz pena
# Processing Record 6 of the Set 7 | praia
# Processing Record 7 of the Set 7 | sanghar
# Processing Record 8 of the Set 7 | san rafael del sur
# Processing Record 9 of the Set 7 | khatanga
# Processing Record 10 of the Set 7 | beringovskiy
# Processing Record 11 of the Set 7 | puerto escondido
# Processing Record 12 of the Set 7 | pevek
# Processing Record 13 of the Set 7 | mangrol
# Processing Record 14 of the Set 7 | talara
# Processing Record 15 of the Set 7 | polur
# Processing Record 16 of the Set 7 | deputatskiy
# Processing Record 17 of the Set 7 | vung tau
# Processing Record 18 of the Set 7 | kysyl-syr
# Processing Record 19 of the Set 7 | perth
# Processing Record 20 of the Set 7 | mehamn
# Processing Record 21 of the Set 7 | hope
# Processing Record 22 of the Set 7 | atar
# Processing Record 23 of the Set 7 | spisska nova ves
# Processing Record 24 of the Set 7 | orange cove
# Processing Record 25 of the Set 7 | bethel
# Processing Record 26 of the Set 7 | severnyy
# Processing Record 27 of the Set 7 | bamako
# Processing Record 28 of the Set 7 | ajdabiya
# Processing Record 29 of the Set 7 | shahdadkot
# Processing Record 30 of the Set 7 | morehead
# Processing Record 31 of the Set 7 | gat
# Processing Record 32 of the Set 7 | mentok
# Processing Record 33 of the Set 7 | rio grande
# Processing Record 34 of the Set 7 | kruisfontein
# Processing Record 35 of the Set 7 | atambua
# Processing Record 36 of the Set 7 | artyom
# Processing Record 37 of the Set 7 | muhos
# Processing Record 38 of the Set 7 | nuuk
# Processing Record 39 of the Set 7 | celestun
# Processing Record 40 of the Set 7 | maua
# Processing Record 41 of the Set 7 | touros
# Processing Record 42 of the Set 7 | bambanglipuro
# Processing Record 43 of the Set 7 | zelenoborskiy
# Processing Record 44 of the Set 7 | launceston
# Processing Record 45 of the Set 7 | merrill
# Processing Record 46 of the Set 7 | ayagoz
# Processing Record 47 of the Set 7 | barrhead
# Processing Record 48 of the Set 7 | vila franca do campo
# Processing Record 49 of the Set 7 | aromashevo
# Processing Record 50 of the Set 7 | kurush
# Processing Record 1 of the Set 8 | charagua
# Processing Record 2 of the Set 8 | vostok
# Processing Record 3 of the Set 8 | mosbach
# Processing Record 4 of the Set 8 | lorengau
# Processing Record 5 of the Set 8 | provost
# Processing Record 6 of the Set 8 | popondetta
# Processing Record 7 of the Set 8 | namatanai
# Processing Record 8 of the Set 8 | souillac
# Processing Record 9 of the Set 8 | emerald
# Processing Record 10 of the Set 8 | nouadhibou
# Processing Record 11 of the Set 8 | agdam
# Processing Record 12 of the Set 8 | vyartsilya
# Processing Record 13 of the Set 8 | anderson
# Processing Record 14 of the Set 8 | grudziadz
# Processing Record 15 of the Set 8 | lamu
# Processing Record 16 of the Set 8 | nelson bay
# Processing Record 17 of the Set 8 | saint-denis
# Processing Record 18 of the Set 8 | zhigansk
# Processing Record 19 of the Set 8 | dayong
# Processing Record 20 of the Set 8 | oneonta
# Processing Record 21 of the Set 8 | qesarya
# Processing Record 22 of the Set 8 | altar
# Processing Record 23 of the Set 8 | yeppoon
# Processing Record 24 of the Set 8 | longlac
# Processing Record 25 of the Set 8 | corinto
# Processing Record 26 of the Set 8 | xuddur
# Processing Record 27 of the Set 8 | saleaula
# City not found. Skipping...
# Processing Record 28 of the Set 8 | coahuayana
# Processing Record 29 of the Set 8 | moctezuma
# Processing Record 30 of the Set 8 | los llanos de aridane
# Processing Record 31 of the Set 8 | bonthe
# Processing Record 32 of the Set 8 | severo-kurilsk
# Processing Record 33 of the Set 8 | umzimvubu
# Processing Record 34 of the Set 8 | iquitos
# Processing Record 35 of the Set 8 | pascagoula
# Processing Record 36 of the Set 8 | culiacan
# Processing Record 37 of the Set 8 | iguape
# Processing Record 38 of the Set 8 | bathsheba
# Processing Record 39 of the Set 8 | haines junction
# Processing Record 40 of the Set 8 | antofagasta
# Processing Record 41 of the Set 8 | agadir
# Processing Record 42 of the Set 8 | skjervoy
# Processing Record 43 of the Set 8 | yumen
# Processing Record 44 of the Set 8 | vygonichi
# Processing Record 45 of the Set 8 | pulaski
# Processing Record 46 of the Set 8 | awbari
# Processing Record 47 of the Set 8 | iqaluit
# Processing Record 48 of the Set 8 | puerto narino
# Processing Record 49 of the Set 8 | ipero
# Processing Record 50 of the Set 8 | kigoma
# Processing Record 1 of the Set 9 | dabat
# Processing Record 2 of the Set 9 | clyde river
# Processing Record 3 of the Set 9 | sentyabrskiy
# Processing Record 4 of the Set 9 | kavaratti
# Processing Record 5 of the Set 9 | hualmay
# Processing Record 6 of the Set 9 | lata
# Processing Record 7 of the Set 9 | uusikaupunki
# Processing Record 8 of the Set 9 | lethem
# Processing Record 9 of the Set 9 | saint-augustin
# Processing Record 10 of the Set 9 | brae
# Processing Record 11 of the Set 9 | bereda
# Processing Record 12 of the Set 9 | chapleau
# Processing Record 13 of the Set 9 | labuan
# Processing Record 14 of the Set 9 | rungata
# Processing Record 15 of the Set 9 | moss point
# Processing Record 16 of the Set 9 | grand centre
# Processing Record 17 of the Set 9 | tura
# Processing Record 18 of the Set 9 | ostersund
# Processing Record 19 of the Set 9 | svetlogorsk
# Processing Record 20 of the Set 9 | mwinilunga
# Processing Record 21 of the Set 9 | port lincoln
# Processing Record 22 of the Set 9 | karoi
# Processing Record 23 of the Set 9 | santa cruz
# Processing Record 24 of the Set 9 | gallup
# Processing Record 25 of the Set 9 | kumo
# Processing Record 26 of the Set 9 | ballina
# Processing Record 27 of the Set 9 | batangafo
# Processing Record 28 of the Set 9 | seydi
# Processing Record 29 of the Set 9 | wuxue
# Processing Record 30 of the Set 9 | foix
# Processing Record 31 of the Set 9 | kushmurun
# Processing Record 32 of the Set 9 | dunedin
# Processing Record 33 of the Set 9 | nyuksenitsa
# Processing Record 34 of the Set 9 | minab
# Processing Record 35 of the Set 9 | rebrikha
# Processing Record 36 of the Set 9 | bonavista
# Processing Record 37 of the Set 9 | geneva
# Processing Record 38 of the Set 9 | sabha
# Processing Record 39 of the Set 9 | marsh harbour
# Processing Record 40 of the Set 9 | kaoma
# Processing Record 41 of the Set 9 | ellisras
# Processing Record 42 of the Set 9 | santa isabel
# Processing Record 43 of the Set 9 | byron bay
# Processing Record 44 of the Set 9 | kirakira
# Processing Record 45 of the Set 9 | keetmanshoop
# Processing Record 46 of the Set 9 | svetlaya
# Processing Record 47 of the Set 9 | hofn
# Processing Record 48 of the Set 9 | verkhnyaya inta
# Processing Record 49 of the Set 9 | malanje
# Processing Record 50 of the Set 9 | moussoro
# Processing Record 1 of the Set 10 | port hardy
# Processing Record 2 of the Set 10 | izumo
# Processing Record 3 of the Set 10 | mount gambier
# Processing Record 4 of the Set 10 | la rioja
# Processing Record 5 of the Set 10 | chara
# Processing Record 6 of the Set 10 | bundaberg
# Processing Record 7 of the Set 10 | dalianwan
# Processing Record 8 of the Set 10 | araripe
# Processing Record 9 of the Set 10 | port hedland
# Processing Record 10 of the Set 10 | victor harbor
# Processing Record 11 of the Set 10 | havoysund
# Processing Record 12 of the Set 10 | guiyang
# Processing Record 13 of the Set 10 | saint pete beach
# Processing Record 14 of the Set 10 | ahipara
# Processing Record 15 of the Set 10 | airai
# Processing Record 16 of the Set 10 | edson
# Processing Record 17 of the Set 10 | san cristobal
# Processing Record 18 of the Set 10 | pringsewu
# Processing Record 19 of the Set 10 | okha
# Processing Record 20 of the Set 10 | buin
# Processing Record 21 of the Set 10 | kismayo
# Processing Record 22 of the Set 10 | la ronge
# Processing Record 23 of the Set 10 | zaragoza
# Processing Record 24 of the Set 10 | portland
# Processing Record 25 of the Set 10 | chokurdakh
# Processing Record 26 of the Set 10 | anori
# Processing Record 27 of the Set 10 | eyl
# Processing Record 28 of the Set 10 | mitchell
# Processing Record 29 of the Set 10 | maceio
# Processing Record 30 of the Set 10 | sovetskiy
# Processing Record 31 of the Set 10 | tubuala
# Processing Record 32 of the Set 10 | ottawa
# Processing Record 33 of the Set 10 | tabas
# Processing Record 34 of the Set 10 | buchanan
# Processing Record 35 of the Set 10 | ballina
# Processing Record 36 of the Set 10 | half moon bay
# Processing Record 37 of the Set 10 | zyryanka
# Processing Record 38 of the Set 10 | steinbach
# Processing Record 39 of the Set 10 | puerto ayacucho
# Processing Record 40 of the Set 10 | coron
# Processing Record 41 of the Set 10 | caibarien
# Processing Record 42 of the Set 10 | mikhaylovka
# Processing Record 43 of the Set 10 | lasa
# Processing Record 44 of the Set 10 | bargal
# Processing Record 45 of the Set 10 | sabinas hidalgo
# Processing Record 46 of the Set 10 | nanortalik
# Processing Record 47 of the Set 10 | panguna
# Processing Record 48 of the Set 10 | phan rang
# Processing Record 49 of the Set 10 | marevo
# Processing Record 50 of the Set 10 | san luis
# Processing Record 1 of the Set 11 | tual
# Processing Record 2 of the Set 11 | kurchum
# Processing Record 3 of the Set 11 | abashiri
# Processing Record 4 of the Set 11 | karratha
# Processing Record 5 of the Set 11 | guerrero negro
# Processing Record 6 of the Set 11 | oksfjord
# Processing Record 7 of the Set 11 | karasburg
# Processing Record 8 of the Set 11 | nizhniy odes
# Processing Record 9 of the Set 11 | sabang
# Processing Record 10 of the Set 11 | suna
# Processing Record 11 of the Set 11 | krasnyye chetai
# Processing Record 12 of the Set 11 | sungaipenuh
# Processing Record 13 of the Set 11 | vila velha
# Processing Record 14 of the Set 11 | adrar
# Processing Record 15 of the Set 11 | najran
# Processing Record 16 of the Set 11 | pushkino
# Processing Record 17 of the Set 11 | khuzdar
# Processing Record 18 of the Set 11 | hamilton
# Processing Record 19 of the Set 11 | arroio grande
# Processing Record 20 of the Set 11 | kijang
# Processing Record 21 of the Set 11 | promyshlennyy
# Processing Record 22 of the Set 11 | vestmannaeyjar
# Processing Record 23 of the Set 11 | waingapu
# Processing Record 24 of the Set 11 | kawalu
# Processing Record 25 of the Set 11 | pucallpa
# Processing Record 26 of the Set 11 | maarianhamina
# Processing Record 27 of the Set 11 | sao felix do xingu
# Processing Record 28 of the Set 11 | bulungu
# Processing Record 29 of the Set 11 | kungurtug
# Processing Record 30 of the Set 11 | sfantu gheorghe
# Processing Record 31 of the Set 11 | midland
# Processing Record 32 of the Set 11 | hami
# Processing Record 33 of the Set 11 | gornyy
# Processing Record 34 of the Set 11 | suamico
# Processing Record 35 of the Set 11 | tongliao
# Processing Record 36 of the Set 11 | shache
# Processing Record 37 of the Set 11 | monatele
# Processing Record 38 of the Set 11 | manvi
# Processing Record 39 of the Set 11 | mount isa
# Processing Record 40 of the Set 11 | chicama
# Processing Record 41 of the Set 11 | alice town
# Processing Record 42 of the Set 11 | bandar
# Processing Record 43 of the Set 11 | altay
# Processing Record 44 of the Set 11 | roma
# Processing Record 45 of the Set 11 | ponca city
# Processing Record 46 of the Set 11 | ambilobe
# Processing Record 47 of the Set 11 | sillod
# Processing Record 48 of the Set 11 | kamaishi
# Processing Record 49 of the Set 11 | yelizovo
# Processing Record 50 of the Set 11 | rawson
# Processing Record 1 of the Set 12 | faanui
# Processing Record 2 of the Set 12 | kirando
# Processing Record 3 of the Set 12 | qandahar
# Processing Record 4 of the Set 12 | pozo colorado
# Processing Record 5 of the Set 12 | havre-saint-pierre
# Processing Record 6 of the Set 12 | beloha
# Processing Record 7 of the Set 12 | paucartambo
# Processing Record 8 of the Set 12 | misterbianco
# Processing Record 9 of the Set 12 | galle
# Processing Record 10 of the Set 12 | manokwari
# Processing Record 11 of the Set 12 | tarudant
# Processing Record 12 of the Set 12 | soller
# Processing Record 13 of the Set 12 | toora-khem
# Processing Record 14 of the Set 12 | hihifo
# Processing Record 15 of the Set 12 | bowral
# Processing Record 16 of the Set 12 | naze
# Processing Record 17 of the Set 12 | tabiauea
# Processing Record 18 of the Set 12 | genhe
# Processing Record 19 of the Set 12 | susanville
# Processing Record 20 of the Set 12 | semenivka
# Processing Record 21 of the Set 12 | mana
# Processing Record 22 of the Set 12 | mabaruma
# Processing Record 23 of the Set 12 | moen
# Processing Record 24 of the Set 12 | palu
# Processing Record 25 of the Set 12 | te anau
# Processing Record 26 of the Set 12 | gondanglegi
# Processing Record 27 of the Set 12 | northam
# Processing Record 28 of the Set 12 | santa rosa
# Processing Record 29 of the Set 12 | clermont
# Processing Record 30 of the Set 12 | san pedro
# Processing Record 31 of the Set 12 | estancia
# Processing Record 32 of the Set 12 | ozuluama
# Processing Record 33 of the Set 12 | haverfordwest
# Processing Record 34 of the Set 12 | port macquarie
# Processing Record 35 of the Set 12 | am timan
# Processing Record 36 of the Set 12 | lesnoy
# Processing Record 37 of the Set 12 | nam tha
# Processing Record 38 of the Set 12 | aklavik
# Processing Record 39 of the Set 12 | evensk
# Processing Record 40 of the Set 12 | finschhafen
# Processing Record 41 of the Set 12 | phangnga
# Processing Record 42 of the Set 12 | contagem
# Processing Record 43 of the Set 12 | norman wells
# Processing Record 44 of the Set 12 | medea
# Processing Record 45 of the Set 12 | wanning
# Processing Record 46 of the Set 12 | bartica
# Processing Record 47 of the Set 12 | sirvintos
# Processing Record 48 of the Set 12 | korla
# Processing Record 49 of the Set 12 | tanshui
# Processing Record 50 of the Set 12 | muli
# Processing Record 1 of the Set 13 | bacuit
# Processing Record 2 of the Set 13 | vallenar
# Processing Record 3 of the Set 13 | samarinda
# Processing Record 4 of the Set 13 | nome
# Processing Record 5 of the Set 13 | reyes
# Processing Record 6 of the Set 13 | viedma
# Processing Record 7 of the Set 13 | lagunas
# Processing Record 8 of the Set 13 | sao filipe
# Processing Record 9 of the Set 13 | nuevo progreso
# Processing Record 10 of the Set 13 | nizhnevartovsk
# Processing Record 11 of the Set 13 | shingu
# Processing Record 12 of the Set 13 | santa ana
# Processing Record 13 of the Set 13 | pimenta bueno
# Processing Record 14 of the Set 13 | qaqortoq
# Processing Record 15 of the Set 13 | coracao de jesus
# Processing Record 16 of the Set 13 | lola
# Processing Record 17 of the Set 13 | talnakh
# Processing Record 18 of the Set 13 | rawannawi
# Processing Record 19 of the Set 13 | wajima
# Processing Record 20 of the Set 13 | synya
# Processing Record 21 of the Set 13 | hasaki
# Processing Record 22 of the Set 13 | boende
# Processing Record 23 of the Set 13 | oranjestad
# Processing Record 24 of the Set 13 | key largo
# Processing Record 25 of the Set 13 | halifax
# Processing Record 26 of the Set 13 | nagaur
# Processing Record 27 of the Set 13 | dankaur
# Processing Record 28 of the Set 13 | brenham
# Processing Record 29 of the Set 13 | balimo
# Processing Record 30 of the Set 13 | praya
# Processing Record 31 of the Set 13 | umm kaddadah
# Processing Record 32 of the Set 13 | granada
# Processing Record 33 of the Set 13 | prince rupert
# Processing Record 34 of the Set 13 | kon tum
# Processing Record 35 of the Set 13 | hay river
# Processing Record 36 of the Set 13 | chalon-sur-saone
# Processing Record 37 of the Set 13 | port hawkesbury
# Processing Record 38 of the Set 13 | bafq
# Processing Record 39 of the Set 13 | isla mujeres
# Processing Record 40 of the Set 13 | pervomayskoye
# Processing Record 41 of the Set 13 | gigmoto
# Processing Record 42 of the Set 13 | campos altos
# Processing Record 43 of the Set 13 | cartagena
# Processing Record 44 of the Set 13 | chiquilistlan
# Processing Record 45 of the Set 13 | kholodnyy
# Processing Record 46 of the Set 13 | meulaboh
# Processing Record 47 of the Set 13 | emba
# Processing Record 48 of the Set 13 | waitati
# Processing Record 49 of the Set 13 | palabuhanratu
# Processing Record 50 of the Set 13 | mersing
# Processing Record 1 of the Set 14 | eldikan
# Processing Record 2 of the Set 14 | sur
# Processing Record 3 of the Set 14 | grass valley
# Processing Record 4 of the Set 14 | gladstone
# Processing Record 5 of the Set 14 | teya
# Processing Record 6 of the Set 14 | nantucket
# Processing Record 7 of the Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of the Set 14 | comodoro rivadavia
# Processing Record 9 of the Set 14 | mattru
# Processing Record 10 of the Set 14 | fujin
# Processing Record 11 of the Set 14 | saldanha
# Processing Record 12 of the Set 14 | isiro
# Processing Record 13 of the Set 14 | olinda
# Processing Record 14 of the Set 14 | krasnoselkup
# Processing Record 15 of the Set 14 | merauke
# Processing Record 16 of the Set 14 | melbu
# Processing Record 17 of the Set 14 | grand gaube
# Processing Record 18 of the Set 14 | tateyama
# Processing Record 19 of the Set 14 | mednogorsk
# Processing Record 20 of the Set 14 | kloulklubed
# Processing Record 21 of the Set 14 | cap malheureux
# Processing Record 22 of the Set 14 | navahrudak
# Processing Record 23 of the Set 14 | mandera
# Processing Record 24 of the Set 14 | nur
# Processing Record 25 of the Set 14 | barawe
# Processing Record 26 of the Set 14 | saint-francois
# Processing Record 27 of the Set 14 | hanna
# Processing Record 28 of the Set 14 | pangody
# Processing Record 29 of the Set 14 | kudahuvadhoo
# Processing Record 30 of the Set 14 | olean
# Processing Record 31 of the Set 14 | freeport
# Processing Record 32 of the Set 14 | takoradi
# Processing Record 33 of the Set 14 | mahajanga
# Processing Record 34 of the Set 14 | skalistyy
# Processing Record 35 of the Set 14 | balaipungut
# Processing Record 36 of the Set 14 | nombre de dios
# Processing Record 37 of the Set 14 | fasa
# Processing Record 38 of the Set 14 | zinder
# Processing Record 39 of the Set 14 | dzhusaly
# Processing Record 40 of the Set 14 | georgiyevka
# Processing Record 41 of the Set 14 | gao
# Processing Record 42 of the Set 14 | giresun
# Processing Record 43 of the Set 14 | kutum
# Processing Record 44 of the Set 14 | itaueira
# Processing Record 45 of the Set 14 | carbonia
# Processing Record 46 of the Set 14 | udachnyy
# Processing Record 47 of the Set 14 | mareeba
# Processing Record 48 of the Set 14 | carora
# Processing Record 49 of the Set 14 | lazaro cardenas
# Processing Record 50 of the Set 14 | sinnamary
# Processing Record 1 of the Set 15 | kuche
# Processing Record 2 of the Set 15 | sorland
# Processing Record 3 of the Set 15 | mackenzie
# Processing Record 4 of the Set 15 | toowoomba
# Processing Record 5 of the Set 15 | agucadoura
# Processing Record 6 of the Set 15 | tambura
# Processing Record 7 of the Set 15 | westport
# Processing Record 8 of the Set 15 | catuday
# Processing Record 9 of the Set 15 | toliary
# Processing Record 10 of the Set 15 | chulman
# Processing Record 11 of the Set 15 | longyan
# Processing Record 12 of the Set 15 | sioux lookout
# Processing Record 13 of the Set 15 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 14 of the Set 15 | punuare
# Processing Record 15 of the Set 15 | ovalle
# Processing Record 16 of the Set 15 | aliwal north
# Processing Record 17 of the Set 15 | kazalinsk
# Processing Record 18 of the Set 15 | dandong
# Processing Record 19 of the Set 15 | peniche
# Processing Record 20 of the Set 15 | kalmar
# Processing Record 21 of the Set 15 | rovaniemi
# Processing Record 22 of the Set 15 | gaurela
# Processing Record 23 of the Set 15 | kununurra
# Processing Record 24 of the Set 15 | ormond beach
# Processing Record 25 of the Set 15 | suluq
# Processing Record 26 of the Set 15 | srednekolymsk
# Processing Record 27 of the Set 15 | rincon
# Processing Record 28 of the Set 15 | yantal
# Processing Record 29 of the Set 15 | sangin
# Processing Record 30 of the Set 15 | vila
# Processing Record 31 of the Set 15 | thinadhoo
# Processing Record 32 of the Set 15 | carballo
# Processing Record 33 of the Set 15 | balkhash
# Processing Record 34 of the Set 15 | waw
# Processing Record 35 of the Set 15 | george
# Processing Record 36 of the Set 15 | rocha
# Processing Record 37 of the Set 15 | coria
# Processing Record 38 of the Set 15 | tunoshna
# Processing Record 39 of the Set 15 | rurrenabaque
# Processing Record 40 of the Set 15 | katsina
# Processing Record 41 of the Set 15 | laguna
# Processing Record 42 of the Set 15 | altagracia de orituco
# Processing Record 43 of the Set 15 | bisho
# Processing Record 44 of the Set 15 | port-de-paix
# Processing Record 45 of the Set 15 | paita
# Processing Record 46 of the Set 15 | jiuquan
# Processing Record 47 of the Set 15 | vega de alatorre
# Processing Record 48 of the Set 15 | nowa ruda
# Processing Record 49 of the Set 15 | quelimane
# Processing Record 50 of the Set 15 | kalyazin
# Processing Record 1 of the Set 16 | jawhar
# Processing Record 2 of the Set 16 | bandundu
# Processing Record 3 of the Set 16 | adilcevaz
# Processing Record 4 of the Set 16 | grants
# Processing Record 5 of the Set 16 | nong khai
# Processing Record 6 of the Set 16 | banmo
# City not found. Skipping...
# Processing Record 7 of the Set 16 | turayf
# Processing Record 8 of the Set 16 | imeni poliny osipenko
# Processing Record 9 of the Set 16 | nioro
# Processing Record 10 of the Set 16 | dongying
# Processing Record 11 of the Set 16 | manta
# Processing Record 12 of the Set 16 | dukat
# Processing Record 13 of the Set 16 | saint-georges
# Processing Record 14 of the Set 16 | ranong
# Processing Record 15 of the Set 16 | shiraz
# Processing Record 16 of the Set 16 | loralai
# Processing Record 17 of the Set 16 | broome
# Processing Record 18 of the Set 16 | jalu
# Processing Record 19 of the Set 16 | cascais
# Processing Record 20 of the Set 16 | abu kamal
# Processing Record 21 of the Set 16 | karkaralinsk
# Processing Record 22 of the Set 16 | katangli
# Processing Record 23 of the Set 16 | harnosand
# Processing Record 24 of the Set 16 | potosi
# Processing Record 25 of the Set 16 | bontang
# Processing Record 26 of the Set 16 | seymchan
# Processing Record 27 of the Set 16 | hailar
# Processing Record 28 of the Set 16 | saint-pierre
# Processing Record 29 of the Set 16 | jabiru
# Processing Record 30 of the Set 16 | haibowan
# Processing Record 31 of the Set 16 | ampanihy
# Processing Record 32 of the Set 16 | lakatoro
# Processing Record 33 of the Set 16 | acapulco
# Processing Record 34 of the Set 16 | seybaplaya
# Processing Record 35 of the Set 16 | annan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 780

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  37.2707 -76.7075     83.95        78          75
# 1     Upernavik      GL  65.6145 -37.6368     42.96        79          86
# 2     Busselton      GB  51.0333  -4.2167     66.38        91          16
# 3        Castro      BR -24.7911 -50.0119     37.13        66           0
# 4  Puerto Ayora      EC  -0.7393 -90.3518     72.55        89          47
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1        4.61     overcast clouds
# 2        3.62          few clouds
# 3        7.61           clear sky
# 4        5.01    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
