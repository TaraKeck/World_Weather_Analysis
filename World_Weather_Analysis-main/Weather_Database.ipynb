# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module.
cities = []

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# %%
#Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=441aa9a01fdf53c411df6287cb0e1c23

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# base url 
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | cherskiy
# Processing Record 2 of the Set 1 | saint-philippe
# Processing Record 3 of the Set 1 | dunedin
# Processing Record 4 of the Set 1 | tocopilla
# Processing Record 5 of the Set 1 | bud
# Processing Record 6 of the Set 1 | hilo
# Processing Record 7 of the Set 1 | kismayo
# Processing Record 8 of the Set 1 | jamestown
# Processing Record 9 of the Set 1 | yasnyy
# Processing Record 10 of the Set 1 | norman wells
# Processing Record 11 of the Set 1 | kuusamo
# Processing Record 12 of the Set 1 | alexandria
# Processing Record 13 of the Set 1 | chuy
# Processing Record 14 of the Set 1 | bethel
# Processing Record 15 of the Set 1 | cidreira
# Processing Record 16 of the Set 1 | qaanaaq
# Processing Record 17 of the Set 1 | kapaa
# Processing Record 18 of the Set 1 | kodiak
# Processing Record 19 of the Set 1 | talaya
# Processing Record 20 of the Set 1 | carnarvon
# Processing Record 21 of the Set 1 | healdsburg
# Processing Record 22 of the Set 1 | burnie
# Processing Record 23 of the Set 1 | nikolskoye
# Processing Record 24 of the Set 1 | jizan
# Processing Record 25 of the Set 1 | cape town
# Processing Record 26 of the Set 1 | saint george
# Processing Record 27 of the Set 1 | mandera
# Processing Record 28 of the Set 1 | khatanga
# Processing Record 29 of the Set 1 | flinders
# Processing Record 30 of the Set 1 | rikitea
# Processing Record 31 of the Set 1 | attawapiskat
# Processing Record 32 of the Set 1 | nushki
# Processing Record 33 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of the Set 1 | zalegoshch
# Processing Record 35 of the Set 1 | narsaq
# Processing Record 36 of the Set 1 | campo grande
# Processing Record 37 of the Set 1 | castro
# Processing Record 38 of the Set 1 | broome
# Processing Record 39 of the Set 1 | puerto ayora
# Processing Record 40 of the Set 1 | busselton
# Processing Record 41 of the Set 1 | avarua
# Processing Record 42 of the Set 1 | vaini
# Processing Record 43 of the Set 1 | chernyshevskiy
# Processing Record 44 of the Set 1 | egvekinot
# Processing Record 45 of the Set 1 | kawalu
# Processing Record 46 of the Set 1 | lesnoy
# Processing Record 47 of the Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 48 of the Set 1 | honavar
# Processing Record 49 of the Set 1 | lavrentiya
# Processing Record 50 of the Set 1 | sentyabrskiy
# Processing Record 1 of the Set 2 | ribeira grande
# Processing Record 2 of the Set 2 | ovalle
# Processing Record 3 of the Set 2 | east london
# Processing Record 4 of the Set 2 | barrow
# Processing Record 5 of the Set 2 | ushuaia
# Processing Record 6 of the Set 2 | port elizabeth
# Processing Record 7 of the Set 2 | iqaluit
# Processing Record 8 of the Set 2 | olafsvik
# Processing Record 9 of the Set 2 | fairbanks
# Processing Record 10 of the Set 2 | port-gentil
# Processing Record 11 of the Set 2 | guarapari
# Processing Record 12 of the Set 2 | punta arenas
# Processing Record 13 of the Set 2 | walvis bay
# Processing Record 14 of the Set 2 | butaritari
# Processing Record 15 of the Set 2 | yerbogachen
# Processing Record 16 of the Set 2 | berezovka
# Processing Record 17 of the Set 2 | nome
# Processing Record 18 of the Set 2 | lagoa
# Processing Record 19 of the Set 2 | burns lake
# Processing Record 20 of the Set 2 | kavieng
# Processing Record 21 of the Set 2 | chumikan
# Processing Record 22 of the Set 2 | pacific grove
# Processing Record 23 of the Set 2 | noumea
# Processing Record 24 of the Set 2 | bontang
# Processing Record 25 of the Set 2 | lebu
# Processing Record 26 of the Set 2 | shibarghan
# City not found. Skipping...
# Processing Record 27 of the Set 2 | richards bay
# Processing Record 28 of the Set 2 | pokrovsk
# Processing Record 29 of the Set 2 | vila franca do campo
# Processing Record 30 of the Set 2 | gazli
# Processing Record 31 of the Set 2 | albany
# Processing Record 32 of the Set 2 | port alfred
# Processing Record 33 of the Set 2 | novaya mayna
# Processing Record 34 of the Set 2 | bluff
# Processing Record 35 of the Set 2 | tuktoyaktuk
# Processing Record 36 of the Set 2 | otane
# Processing Record 37 of the Set 2 | beloha
# City not found. Skipping...
# Processing Record 38 of the Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of the Set 2 | vestmannaeyjar
# Processing Record 40 of the Set 2 | kaitangata
# Processing Record 41 of the Set 2 | hermanus
# Processing Record 42 of the Set 2 | klaksvik
# Processing Record 43 of the Set 2 | kieta
# Processing Record 44 of the Set 2 | upernavik
# Processing Record 45 of the Set 2 | numan
# Processing Record 46 of the Set 2 | komsomolskiy
# Processing Record 47 of the Set 2 | brodokalmak
# Processing Record 48 of the Set 2 | sterling
# Processing Record 49 of the Set 2 | ilulissat
# Processing Record 50 of the Set 2 | hithadhoo
# Processing Record 1 of the Set 3 | bogovarovo
# Processing Record 2 of the Set 3 | samusu
# City not found. Skipping...
# Processing Record 3 of the Set 3 | marang
# Processing Record 4 of the Set 3 | bowen
# Processing Record 5 of the Set 3 | airai
# Processing Record 6 of the Set 3 | simpang
# Processing Record 7 of the Set 3 | mys shmidta
# Processing Record 8 of the Set 3 | chokurdakh
# Processing Record 9 of the Set 3 | minyar
# Processing Record 10 of the Set 3 | lormi
# Processing Record 11 of the Set 3 | correntina
# Processing Record 12 of the Set 3 | belmonte
# Processing Record 13 of the Set 3 | itarema
# Processing Record 14 of the Set 3 | saldanha
# Processing Record 15 of the Set 3 | huarmey
# Processing Record 16 of the Set 3 | ponta do sol
# Processing Record 17 of the Set 3 | yellowknife
# Processing Record 18 of the Set 3 | port shepstone
# Processing Record 19 of the Set 3 | pangnirtung
# Processing Record 20 of the Set 3 | mataura
# Processing Record 21 of the Set 3 | belushya guba
# Processing Record 22 of the Set 3 | rocha
# Processing Record 23 of the Set 3 | safford
# Processing Record 24 of the Set 3 | senador jose porfirio
# Processing Record 25 of the Set 3 | izhma
# Processing Record 26 of the Set 3 | sola
# Processing Record 27 of the Set 3 | pokhara
# Processing Record 28 of the Set 3 | trairi
# Processing Record 29 of the Set 3 | susehri
# Processing Record 30 of the Set 3 | pailon
# Processing Record 31 of the Set 3 | severo-kurilsk
# Processing Record 32 of the Set 3 | new norfolk
# Processing Record 33 of the Set 3 | san patricio
# Processing Record 34 of the Set 3 | harper
# Processing Record 35 of the Set 3 | brainerd
# Processing Record 36 of the Set 3 | loa janan
# Processing Record 37 of the Set 3 | georgetown
# Processing Record 38 of the Set 3 | illoqqortoormiut
# Processing Record 39 of the Set 3 | dillon
# Processing Record 40 of the Set 3 | mahebourg
# Processing Record 41 of the Set 3 | simbahan
# Processing Record 42 of the Set 3 | clyde river
# Processing Record 43 of the Set 3 | wajid
# Processing Record 44 of the Set 3 | yanan
# City not found. Skipping...
# Processing Record 45 of the Set 3 | bang rakam
# Processing Record 46 of the Set 3 | beyneu
# City not found. Skipping...
# Processing Record 47 of the Set 3 | adrar
# Processing Record 48 of the Set 3 | margate
# Processing Record 49 of the Set 3 | aksarka
# Processing Record 50 of the Set 3 | verkhnyaya inta
# Processing Record 1 of the Set 4 | esmeraldas
# Processing Record 2 of the Set 4 | high rock
# Processing Record 3 of the Set 4 | teknaf
# Processing Record 4 of the Set 4 | tirumullaivasal
# Processing Record 5 of the Set 4 | villacarrillo
# Processing Record 6 of the Set 4 | coquimbo
# Processing Record 7 of the Set 4 | miura
# Processing Record 8 of the Set 4 | ambovombe
# City not found. Skipping...
# Processing Record 9 of the Set 4 | machilipatnam
# Processing Record 10 of the Set 4 | husavik
# Processing Record 11 of the Set 4 | teahupoo
# Processing Record 12 of the Set 4 | weligama
# Processing Record 13 of the Set 4 | atuona
# Processing Record 14 of the Set 4 | biak
# Processing Record 15 of the Set 4 | saint-pierre
# Processing Record 16 of the Set 4 | leningradskiy
# Processing Record 17 of the Set 4 | nuevo progreso
# Processing Record 18 of the Set 4 | gladstone
# Processing Record 19 of the Set 4 | honiara
# Processing Record 20 of the Set 4 | longyearbyen
# Processing Record 21 of the Set 4 | grafton
# Processing Record 22 of the Set 4 | kamenka
# Processing Record 23 of the Set 4 | isangel
# Processing Record 24 of the Set 4 | kamenskoye
# Processing Record 25 of the Set 4 | barentsburg
# Processing Record 26 of the Set 4 | kavaratti
# Processing Record 27 of the Set 4 | muzhi
# Processing Record 28 of the Set 4 | pombas
# Processing Record 29 of the Set 4 | cape elizabeth
# Processing Record 30 of the Set 4 | ifakara
# Processing Record 31 of the Set 4 | armidale
# Processing Record 32 of the Set 4 | meulaboh
# Processing Record 33 of the Set 4 | ginir
# Processing Record 34 of the Set 4 | arraial do cabo
# Processing Record 35 of the Set 4 | torbay
# Processing Record 36 of the Set 4 | high level
# Processing Record 37 of the Set 4 | savannah bight
# Processing Record 38 of the Set 4 | hobart
# Processing Record 39 of the Set 4 | bathsheba
# Processing Record 40 of the Set 4 | pevek
# Processing Record 41 of the Set 4 | hede
# City not found. Skipping...
# Processing Record 42 of the Set 4 | puksoozero
# Processing Record 43 of the Set 4 | cabo san lucas
# Processing Record 44 of the Set 4 | manosque
# Processing Record 45 of the Set 4 | sitka
# Processing Record 46 of the Set 4 | tura
# Processing Record 47 of the Set 4 | goundam
# Processing Record 48 of the Set 4 | vardo
# Processing Record 49 of the Set 4 | key west
# Processing Record 50 of the Set 4 | tasiilaq
# Processing Record 1 of the Set 5 | thompson
# Processing Record 2 of the Set 5 | ahipara
# Processing Record 3 of the Set 5 | samarai
# Processing Record 4 of the Set 5 | dikson
# Processing Record 5 of the Set 5 | padang
# Processing Record 6 of the Set 5 | ancud
# Processing Record 7 of the Set 5 | sena madureira
# Processing Record 8 of the Set 5 | verkhniy rohachyk
# Processing Record 9 of the Set 5 | nanortalik
# Processing Record 10 of the Set 5 | marcona
# Processing Record 11 of the Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 12 of the Set 5 | cacapava do sul
# Processing Record 13 of the Set 5 | mendoza
# Processing Record 14 of the Set 5 | alugan
# Processing Record 15 of the Set 5 | kolda
# Processing Record 16 of the Set 5 | kalga
# Processing Record 17 of the Set 5 | chulman
# Processing Record 18 of the Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 19 of the Set 5 | lolua
# City not found. Skipping...
# Processing Record 20 of the Set 5 | goderich
# Processing Record 21 of the Set 5 | grand river south east
# Processing Record 22 of the Set 5 | lodwar
# Processing Record 23 of the Set 5 | sucevita
# Processing Record 24 of the Set 5 | landau
# Processing Record 25 of the Set 5 | pisco
# Processing Record 26 of the Set 5 | boende
# Processing Record 27 of the Set 5 | kloulklubed
# Processing Record 28 of the Set 5 | chisec
# Processing Record 29 of the Set 5 | buraydah
# Processing Record 30 of the Set 5 | pithiviers
# Processing Record 31 of the Set 5 | american canyon
# Processing Record 32 of the Set 5 | ust-kuyga
# Processing Record 33 of the Set 5 | kahului
# Processing Record 34 of the Set 5 | sao filipe
# Processing Record 35 of the Set 5 | arlit
# Processing Record 36 of the Set 5 | schwedt
# Processing Record 37 of the Set 5 | kattivakkam
# Processing Record 38 of the Set 5 | fortuna
# Processing Record 39 of the Set 5 | yakima
# Processing Record 40 of the Set 5 | lompoc
# Processing Record 41 of the Set 5 | chandbali
# Processing Record 42 of the Set 5 | bambous virieux
# Processing Record 43 of the Set 5 | bolungarvik
# Processing Record 44 of the Set 5 | sento se
# Processing Record 45 of the Set 5 | alofi
# Processing Record 46 of the Set 5 | bredasdorp
# Processing Record 47 of the Set 5 | wilhelmsburg
# Processing Record 48 of the Set 5 | mogocha
# Processing Record 49 of the Set 5 | iracoubo
# Processing Record 50 of the Set 5 | sao gabriel da cachoeira
# Processing Record 1 of the Set 6 | toliary
# City not found. Skipping...
# Processing Record 2 of the Set 6 | tuatapere
# Processing Record 3 of the Set 6 | el badari
# Processing Record 4 of the Set 6 | mount isa
# Processing Record 5 of the Set 6 | caravelas
# Processing Record 6 of the Set 6 | palabuhanratu
# Processing Record 7 of the Set 6 | vilyuysk
# Processing Record 8 of the Set 6 | dinar
# Processing Record 9 of the Set 6 | qaqortoq
# Processing Record 10 of the Set 6 | salalah
# Processing Record 11 of the Set 6 | montevideo
# Processing Record 12 of the Set 6 | portland
# Processing Record 13 of the Set 6 | fenyi
# City not found. Skipping...
# Processing Record 14 of the Set 6 | aloleng
# Processing Record 15 of the Set 6 | cutler ridge
# Processing Record 16 of the Set 6 | dori
# Processing Record 17 of the Set 6 | provideniya
# Processing Record 18 of the Set 6 | grand gaube
# Processing Record 19 of the Set 6 | chernyakhiv
# Processing Record 20 of the Set 6 | ponnani
# Processing Record 21 of the Set 6 | kollam
# Processing Record 22 of the Set 6 | coahuayana
# Processing Record 23 of the Set 6 | saskylakh
# Processing Record 24 of the Set 6 | altamira
# Processing Record 25 of the Set 6 | medicine hat
# Processing Record 26 of the Set 6 | katsuura
# Processing Record 27 of the Set 6 | rungata
# Processing Record 28 of the Set 6 | flin flon
# Processing Record 29 of the Set 6 | krutinka
# Processing Record 30 of the Set 6 | southbridge
# Processing Record 31 of the Set 6 | padilla
# Processing Record 32 of the Set 6 | berdigestyakh
# Processing Record 33 of the Set 6 | lata
# Processing Record 34 of the Set 6 | waipawa
# Processing Record 35 of the Set 6 | tigil
# Processing Record 36 of the Set 6 | mar del plata
# Processing Record 37 of the Set 6 | jiangyou
# City not found. Skipping...
# Processing Record 38 of the Set 6 | pathein
# Processing Record 39 of the Set 6 | athabasca
# Processing Record 40 of the Set 6 | lichinga
# Processing Record 41 of the Set 6 | sinnamary
# Processing Record 42 of the Set 6 | moree
# Processing Record 43 of the Set 6 | shimoda
# Processing Record 44 of the Set 6 | bow island
# Processing Record 45 of the Set 6 | half moon bay
# Processing Record 46 of the Set 6 | thinadhoo
# Processing Record 47 of the Set 6 | charters towers
# Processing Record 48 of the Set 6 | shellbrook
# Processing Record 49 of the Set 6 | guruvayur
# Processing Record 50 of the Set 6 | tchollire
# Processing Record 1 of the Set 7 | berlevag
# Processing Record 2 of the Set 7 | mackenzie
# Processing Record 3 of the Set 7 | poum
# Processing Record 4 of the Set 7 | lorengau
# Processing Record 5 of the Set 7 | la primavera
# Processing Record 6 of the Set 7 | nantucket
# Processing Record 7 of the Set 7 | columbus
# Processing Record 8 of the Set 7 | katherine
# Processing Record 9 of the Set 7 | marquette
# Processing Record 10 of the Set 7 | groton
# Processing Record 11 of the Set 7 | karratha
# Processing Record 12 of the Set 7 | sabha
# Processing Record 13 of the Set 7 | codrington
# Processing Record 14 of the Set 7 | yar-sale
# Processing Record 15 of the Set 7 | pandamatenga
# Processing Record 16 of the Set 7 | basoko
# Processing Record 17 of the Set 7 | oniceni
# Processing Record 18 of the Set 7 | nizhneyansk
# Processing Record 19 of the Set 7 | eyl
# Processing Record 20 of the Set 7 | puro
# Processing Record 21 of the Set 7 | taltal
# Processing Record 22 of the Set 7 | rawson
# Processing Record 23 of the Set 7 | chagda
# Processing Record 24 of the Set 7 | kiama
# Processing Record 25 of the Set 7 | broken hill
# Processing Record 26 of the Set 7 | mizdah
# Processing Record 27 of the Set 7 | raudeberg
# Processing Record 28 of the Set 7 | abbeville
# Processing Record 29 of the Set 7 | esperance
# Processing Record 30 of the Set 7 | lamu
# Processing Record 31 of the Set 7 | saint-joseph
# Processing Record 32 of the Set 7 | road town
# Processing Record 33 of the Set 7 | san quintin
# Processing Record 34 of the Set 7 | velyka kisnytsya
# Processing Record 35 of the Set 7 | vila velha
# Processing Record 36 of the Set 7 | geraldton
# Processing Record 37 of the Set 7 | huanan
# City not found. Skipping...
# Processing Record 38 of the Set 7 | oranjemund
# Processing Record 39 of the Set 7 | kruisfontein
# Processing Record 40 of the Set 7 | dunda
# Processing Record 41 of the Set 7 | tiarei
# Processing Record 42 of the Set 7 | port macquarie
# Processing Record 43 of the Set 7 | svetlogorsk
# Processing Record 44 of the Set 7 | zmeinogorsk
# Processing Record 45 of the Set 7 | port hedland
# Processing Record 46 of the Set 7 | ngunguru
# Processing Record 47 of the Set 7 | kiunga
# Processing Record 48 of the Set 7 | beira
# Processing Record 49 of the Set 7 | praia
# Processing Record 50 of the Set 7 | torrington
# Processing Record 1 of the Set 8 | bodden town
# Processing Record 2 of the Set 8 | kashan
# Processing Record 3 of the Set 8 | victoria
# Processing Record 4 of the Set 8 | namibe
# Processing Record 5 of the Set 8 | gander
# Processing Record 6 of the Set 8 | bokspits
# Processing Record 7 of the Set 8 | udachnyy
# Processing Record 8 of the Set 8 | paranaiba
# Processing Record 9 of the Set 8 | port lincoln
# Processing Record 10 of the Set 8 | hwange
# Processing Record 11 of the Set 8 | hambantota
# Processing Record 12 of the Set 8 | morondava
# City not found. Skipping...
# Processing Record 13 of the Set 8 | maraa
# Processing Record 14 of the Set 8 | scalea
# Processing Record 15 of the Set 8 | clearlake
# Processing Record 16 of the Set 8 | victor harbor
# Processing Record 17 of the Set 8 | aklavik
# Processing Record 18 of the Set 8 | henties bay
# Processing Record 19 of the Set 8 | gouloure
# Processing Record 20 of the Set 8 | petropavlovsk-kamchatskiy
# Processing Record 21 of the Set 8 | semey
# City not found. Skipping...
# Processing Record 22 of the Set 8 | satitoa
# City not found. Skipping...
# Processing Record 23 of the Set 8 | jhalu
# Processing Record 24 of the Set 8 | lovozero
# Processing Record 25 of the Set 8 | havoysund
# Processing Record 26 of the Set 8 | barda
# Processing Record 27 of the Set 8 | souillac
# Processing Record 28 of the Set 8 | sobolevo
# Processing Record 29 of the Set 8 | aban
# Processing Record 30 of the Set 8 | atar
# Processing Record 31 of the Set 8 | yumen
# City not found. Skipping...
# Processing Record 32 of the Set 8 | anadyr
# Processing Record 33 of the Set 8 | poya
# Processing Record 34 of the Set 8 | jalu
# Processing Record 35 of the Set 8 | svetlaya
# Processing Record 36 of the Set 8 | quelimane
# Processing Record 37 of the Set 8 | cayenne
# Processing Record 38 of the Set 8 | hualmay
# Processing Record 39 of the Set 8 | hvide sande
# Processing Record 40 of the Set 8 | zhigansk
# Processing Record 41 of the Set 8 | piacabucu
# Processing Record 42 of the Set 8 | ferrol
# Processing Record 43 of the Set 8 | coihaique
# Processing Record 44 of the Set 8 | opuwo
# Processing Record 45 of the Set 8 | baykit
# Processing Record 46 of the Set 8 | lodja
# Processing Record 47 of the Set 8 | los aquijes
# Processing Record 48 of the Set 8 | boca do acre
# Processing Record 49 of the Set 8 | yulara
# Processing Record 50 of the Set 8 | maceio
# Processing Record 1 of the Set 9 | nakamura
# Processing Record 2 of the Set 9 | broadford
# Processing Record 3 of the Set 9 | jimenez
# Processing Record 4 of the Set 9 | trinidad
# Processing Record 5 of the Set 9 | gat
# Processing Record 6 of the Set 9 | tori fatehpur
# Processing Record 7 of the Set 9 | dvinskoy
# Processing Record 8 of the Set 9 | barra
# Processing Record 9 of the Set 9 | kasongo-lunda
# Processing Record 10 of the Set 9 | palasa
# Processing Record 11 of the Set 9 | wiang sa
# Processing Record 12 of the Set 9 | aleksandrov gay
# Processing Record 13 of the Set 9 | dongsheng
# City not found. Skipping...
# Processing Record 14 of the Set 9 | paciran
# Processing Record 15 of the Set 9 | sinjar
# Processing Record 16 of the Set 9 | boa vista
# Processing Record 17 of the Set 9 | vao
# Processing Record 18 of the Set 9 | yirol
# City not found. Skipping...
# Processing Record 19 of the Set 9 | muros
# Processing Record 20 of the Set 9 | sao jose da coroa grande
# Processing Record 21 of the Set 9 | tukrah
# Processing Record 22 of the Set 9 | moose factory
# Processing Record 23 of the Set 9 | paso de patria
# Processing Record 24 of the Set 9 | sri aman
# Processing Record 25 of the Set 9 | hovd
# Processing Record 26 of the Set 9 | royan
# Processing Record 27 of the Set 9 | katangli
# Processing Record 28 of the Set 9 | rognan
# Processing Record 29 of the Set 9 | san vicente
# Processing Record 30 of the Set 9 | north bend
# Processing Record 31 of the Set 9 | mercedes
# Processing Record 32 of the Set 9 | faanui
# Processing Record 33 of the Set 9 | pangai
# Processing Record 34 of the Set 9 | mount gambier
# Processing Record 35 of the Set 9 | grants
# Processing Record 36 of the Set 9 | pemberton
# Processing Record 37 of the Set 9 | ambilobe
# City not found. Skipping...
# Processing Record 38 of the Set 9 | stephenville
# Processing Record 39 of the Set 9 | balgazyn
# Processing Record 40 of the Set 9 | makinsk
# City not found. Skipping...
# Processing Record 41 of the Set 9 | bonthe
# Processing Record 42 of the Set 9 | amderma
# Processing Record 43 of the Set 9 | sulangan
# Processing Record 44 of the Set 9 | sayyan
# Processing Record 45 of the Set 9 | cururupu
# Processing Record 46 of the Set 9 | ust-maya
# Processing Record 47 of the Set 9 | champerico
# Processing Record 48 of the Set 9 | moctezuma
# Processing Record 49 of the Set 9 | novokubansk
# Processing Record 50 of the Set 9 | dipolog
# Processing Record 1 of the Set 10 | olinda
# Processing Record 2 of the Set 10 | ostrovnoy
# Processing Record 3 of the Set 10 | morgan city
# Processing Record 4 of the Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of the Set 10 | zaykovo
# Processing Record 6 of the Set 10 | ca mau
# Processing Record 7 of the Set 10 | qinzhou
# City not found. Skipping...
# Processing Record 8 of the Set 10 | kandrian
# Processing Record 9 of the Set 10 | taoudenni
# Processing Record 10 of the Set 10 | mergui
# Processing Record 11 of the Set 10 | vilcun
# Processing Record 12 of the Set 10 | lucea
# Processing Record 13 of the Set 10 | bengkulu
# Processing Record 14 of the Set 10 | tilichiki
# Processing Record 15 of the Set 10 | chik
# Processing Record 16 of the Set 10 | white rock
# Processing Record 17 of the Set 10 | sioux lookout
# Processing Record 18 of the Set 10 | chapais
# Processing Record 19 of the Set 10 | ardistan
# Processing Record 20 of the Set 10 | brunswick
# Processing Record 21 of the Set 10 | pundaguitan
# Processing Record 22 of the Set 10 | savonlinna
# Processing Record 23 of the Set 10 | deputatskiy
# Processing Record 24 of the Set 10 | hamilton
# Processing Record 25 of the Set 10 | warqla
# Processing Record 26 of the Set 10 | port pirie
# Processing Record 27 of the Set 10 | bubaque
# Processing Record 28 of the Set 10 | port blair
# Processing Record 29 of the Set 10 | haines junction
# Processing Record 30 of the Set 10 | ambulu
# Processing Record 31 of the Set 10 | chicama
# Processing Record 32 of the Set 10 | ayagoz
# City not found. Skipping...
# Processing Record 33 of the Set 10 | garanhuns
# Processing Record 34 of the Set 10 | bajo baudo
# Processing Record 35 of the Set 10 | rundu
# Processing Record 36 of the Set 10 | mopti
# Processing Record 37 of the Set 10 | aygedzor
# Processing Record 38 of the Set 10 | suraia
# Processing Record 39 of the Set 10 | guerrero negro
# Processing Record 40 of the Set 10 | pando
# Processing Record 41 of the Set 10 | severnyy
# Processing Record 42 of the Set 10 | chachapoyas
# Processing Record 43 of the Set 10 | saint stephen
# Processing Record 44 of the Set 10 | salinopolis
# Processing Record 45 of the Set 10 | keshan
# City not found. Skipping...
# Processing Record 46 of the Set 10 | la paz
# Processing Record 47 of the Set 10 | koslan
# Processing Record 48 of the Set 10 | bay roberts
# Processing Record 49 of the Set 10 | aginskoye
# Processing Record 50 of the Set 10 | ust-bolsheretsk
# Processing Record 1 of the Set 11 | banda aceh
# Processing Record 2 of the Set 11 | hofn
# Processing Record 3 of the Set 11 | beringovskiy
# Processing Record 4 of the Set 11 | warkworth
# Processing Record 5 of the Set 11 | atambua
# Processing Record 6 of the Set 11 | tiksi
# Processing Record 7 of the Set 11 | sept-iles
# Processing Record 8 of the Set 11 | grand-santi
# Processing Record 9 of the Set 11 | clarence town
# Processing Record 10 of the Set 11 | byron bay
# Processing Record 11 of the Set 11 | khonuu
# Processing Record 12 of the Set 11 | marawi
# City not found. Skipping...
# Processing Record 13 of the Set 11 | rincon
# Processing Record 14 of the Set 11 | cockburn town
# Processing Record 15 of the Set 11 | guymon
# Processing Record 16 of the Set 11 | galiwinku
# Processing Record 17 of the Set 11 | kudahuvadhoo
# Processing Record 18 of the Set 11 | dudinka
# Processing Record 19 of the Set 11 | xining
# City not found. Skipping...
# Processing Record 20 of the Set 11 | aldan
# Processing Record 21 of the Set 11 | gurupa
# Processing Record 22 of the Set 11 | ola
# Processing Record 23 of the Set 11 | yelizovo
# Processing Record 24 of the Set 11 | acari
# Processing Record 25 of the Set 11 | escanaba
# Processing Record 26 of the Set 11 | almaznyy
# Processing Record 27 of the Set 11 | moissala
# Processing Record 28 of the Set 11 | mananjary
# City not found. Skipping...
# Processing Record 29 of the Set 11 | talnakh
# Processing Record 30 of the Set 11 | puerto madryn
# Processing Record 31 of the Set 11 | gornopravdinsk
# Processing Record 32 of the Set 11 | wenling
# City not found. Skipping...
# Processing Record 33 of the Set 11 | houma
# Processing Record 34 of the Set 11 | benghazi
# Processing Record 35 of the Set 11 | orange
# Processing Record 36 of the Set 11 | riyadh
# Processing Record 37 of the Set 11 | mecca
# Processing Record 38 of the Set 11 | halalo
# City not found. Skipping...
# Processing Record 39 of the Set 11 | langsa
# Processing Record 40 of the Set 11 | urumqi
# City not found. Skipping...
# Processing Record 41 of the Set 11 | hasaki
# Processing Record 42 of the Set 11 | talakan
# Processing Record 43 of the Set 11 | dalby
# Processing Record 44 of the Set 11 | matadi
# Processing Record 45 of the Set 11 | marsa matruh
# Processing Record 46 of the Set 11 | pilion
# City not found. Skipping...
# Processing Record 47 of the Set 11 | barranca
# Processing Record 48 of the Set 11 | kadykchan
# Processing Record 49 of the Set 11 | tubuala
# Processing Record 50 of the Set 11 | emerald
# Processing Record 1 of the Set 12 | luderitz
# Processing Record 2 of the Set 12 | halifax
# Processing Record 3 of the Set 12 | brae
# Processing Record 4 of the Set 12 | kaeo
# Processing Record 5 of the Set 12 | marfino
# Processing Record 6 of the Set 12 | sisimiut
# Processing Record 7 of the Set 12 | fukue
# Processing Record 8 of the Set 12 | srednekolymsk
# Processing Record 9 of the Set 12 | muli
# Processing Record 10 of the Set 12 | tlaxco
# Processing Record 11 of the Set 12 | bobrovka
# Processing Record 12 of the Set 12 | biu
# Processing Record 13 of the Set 12 | guilin
# City not found. Skipping...
# Processing Record 14 of the Set 12 | gravdal
# Processing Record 15 of the Set 12 | chabahar
# Processing Record 16 of the Set 12 | kuching
# Processing Record 17 of the Set 12 | flagstaff
# Processing Record 18 of the Set 12 | umzimvubu
# Processing Record 19 of the Set 12 | marzuq
# Processing Record 20 of the Set 12 | karibib
# Processing Record 21 of the Set 12 | djibo
# Processing Record 22 of the Set 12 | agadez
# Processing Record 23 of the Set 12 | ermelo
# Processing Record 24 of the Set 12 | talcher
# Processing Record 25 of the Set 12 | tizimin
# Processing Record 26 of the Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of the Set 12 | santa isabel do rio negro
# Processing Record 28 of the Set 12 | lesozavodsk
# Processing Record 29 of the Set 12 | namatanai
# Processing Record 30 of the Set 12 | san juan
# Processing Record 31 of the Set 12 | dekar
# Processing Record 32 of the Set 12 | tharrawaddy
# Processing Record 33 of the Set 12 | chornobay
# Processing Record 34 of the Set 12 | maridi
# City not found. Skipping...
# Processing Record 35 of the Set 12 | nadym
# Processing Record 36 of the Set 12 | pocone
# Processing Record 37 of the Set 12 | concordia
# Processing Record 38 of the Set 12 | bayir
# Processing Record 39 of the Set 12 | antalaha
# City not found. Skipping...
# Processing Record 40 of the Set 12 | ust-nera
# Processing Record 41 of the Set 12 | labuhan
# Processing Record 42 of the Set 12 | borama
# Processing Record 43 of the Set 12 | nishihara
# Processing Record 44 of the Set 12 | timmins
# Processing Record 45 of the Set 12 | bahia honda
# Processing Record 46 of the Set 12 | kalevala
# Processing Record 47 of the Set 12 | mahajanga
# City not found. Skipping...
# Processing Record 48 of the Set 12 | durban
# Processing Record 49 of the Set 12 | xai-xai
# Processing Record 50 of the Set 12 | adiake
# Processing Record 1 of the Set 13 | general roca
# Processing Record 2 of the Set 13 | krasnoselkup
# Processing Record 3 of the Set 13 | bodo
# Processing Record 4 of the Set 13 | bushehr
# Processing Record 5 of the Set 13 | hervey bay
# Processing Record 6 of the Set 13 | griffith
# Processing Record 7 of the Set 13 | san lorenzo
# Processing Record 8 of the Set 13 | mandeville
# Processing Record 9 of the Set 13 | azovo
# Processing Record 10 of the Set 13 | te anau
# Processing Record 11 of the Set 13 | malakal
# City not found. Skipping...
# Processing Record 12 of the Set 13 | uryupinsk
# Processing Record 13 of the Set 13 | malumfashi
# Processing Record 14 of the Set 13 | asau
# City not found. Skipping...
# Processing Record 15 of the Set 13 | warrington
# Processing Record 16 of the Set 13 | qui nhon
# Processing Record 17 of the Set 13 | acajutla
# Processing Record 18 of the Set 13 | shakawe
# Processing Record 19 of the Set 13 | amahai
# Processing Record 20 of the Set 13 | dalsingh sarai
# Processing Record 21 of the Set 13 | raahe
# Processing Record 22 of the Set 13 | umm kaddadah
# City not found. Skipping...
# Processing Record 23 of the Set 13 | palmer
# Processing Record 24 of the Set 13 | san vicente
# Processing Record 25 of the Set 13 | jining
# City not found. Skipping...
# Processing Record 26 of the Set 13 | zlatoustovsk
# Processing Record 27 of the Set 13 | neiafu
# Processing Record 28 of the Set 13 | west wendover
# Processing Record 29 of the Set 13 | sistranda
# Processing Record 30 of the Set 13 | tazmalt
# Processing Record 31 of the Set 13 | makung
# City not found. Skipping...
# Processing Record 32 of the Set 13 | paamiut
# Processing Record 33 of the Set 13 | corvallis
# Processing Record 34 of the Set 13 | ninghai
# City not found. Skipping...
# Processing Record 35 of the Set 13 | bulgan
# Processing Record 36 of the Set 13 | nampula
# Processing Record 37 of the Set 13 | shache
# City not found. Skipping...
# Processing Record 38 of the Set 13 | kamaishi
# Processing Record 39 of the Set 13 | ruatoria
# Processing Record 40 of the Set 13 | shingu
# Processing Record 41 of the Set 13 | mujiayingzi
# City not found. Skipping...
# Processing Record 42 of the Set 13 | zheleznodorozhnyy
# Processing Record 43 of the Set 13 | neuquen
# Processing Record 44 of the Set 13 | shelburne
# Processing Record 45 of the Set 13 | kirakira
# Processing Record 46 of the Set 13 | fallon
# Processing Record 47 of the Set 13 | bima
# Processing Record 48 of the Set 13 | anzio
# Processing Record 49 of the Set 13 | mamakan
# Processing Record 50 of the Set 13 | toccoa
# Processing Record 1 of the Set 14 | obernai
# Processing Record 2 of the Set 14 | muncar
# Processing Record 3 of the Set 14 | ibb
# Processing Record 4 of the Set 14 | yen bai
# Processing Record 5 of the Set 14 | matara
# Processing Record 6 of the Set 14 | ankang
# City not found. Skipping...
# Processing Record 7 of the Set 14 | maumere
# Processing Record 8 of the Set 14 | chifeng
# City not found. Skipping...
# Processing Record 9 of the Set 14 | necochea
# Processing Record 10 of the Set 14 | juifang
# City not found. Skipping...
# Processing Record 11 of the Set 14 | saleaula
# City not found. Skipping...
# Processing Record 12 of the Set 14 | marrakesh
# Processing Record 13 of the Set 14 | college
# Processing Record 14 of the Set 14 | rawannawi
# Processing Record 15 of the Set 14 | inhambane
# Processing Record 16 of the Set 14 | san cristobal
# Processing Record 17 of the Set 14 | kupang
# Processing Record 18 of the Set 14 | akdepe
# Processing Record 19 of the Set 14 | san ignacio
# Processing Record 20 of the Set 14 | cockburn town
# Processing Record 21 of the Set 14 | kaura namoda
# Processing Record 22 of the Set 14 | haukipudas
# Processing Record 23 of the Set 14 | mahibadhoo
# Processing Record 24 of the Set 14 | williston
# Processing Record 25 of the Set 14 | nova bana
# Processing Record 26 of the Set 14 | nipawin
# Processing Record 27 of the Set 14 | moanda
# Processing Record 28 of the Set 14 | montijo
# Processing Record 29 of the Set 14 | waddan
# Processing Record 30 of the Set 14 | hay river
# Processing Record 31 of the Set 14 | saint-augustin
# Processing Record 32 of the Set 14 | mocambique
# Processing Record 33 of the Set 14 | ariquemes
# Processing Record 34 of the Set 14 | laguna
# Processing Record 35 of the Set 14 | mezhdurechensk
# Processing Record 36 of the Set 14 | mitsamiouli
# Processing Record 37 of the Set 14 | fenoarivo
# City not found. Skipping...
# Processing Record 38 of the Set 14 | mayumba
# Processing Record 39 of the Set 14 | baoqing
# City not found. Skipping...
# Processing Record 40 of the Set 14 | tricase
# Processing Record 41 of the Set 14 | viligili
# Processing Record 42 of the Set 14 | tezu
# Processing Record 43 of the Set 14 | mongo
# Processing Record 44 of the Set 14 | aykhal
# Processing Record 45 of the Set 14 | san jeronimo
# Processing Record 46 of the Set 14 | coshocton
# Processing Record 47 of the Set 14 | rovaniemi
# Processing Record 48 of the Set 14 | sakakah
# Processing Record 49 of the Set 14 | mpanda
# Processing Record 50 of the Set 14 | sanchursk
# Processing Record 1 of the Set 15 | comodoro rivadavia
# Processing Record 2 of the Set 15 | honningsvag
# Processing Record 3 of the Set 15 | ossora
# Processing Record 4 of the Set 15 | vanavara
# Processing Record 5 of the Set 15 | juybar
# Processing Record 6 of the Set 15 | chanika
# Processing Record 7 of the Set 15 | goure
# Processing Record 8 of the Set 15 | vostochnyy
# Processing Record 9 of the Set 15 | la plata
# Processing Record 10 of the Set 15 | cap malheureux
# Processing Record 11 of the Set 15 | tucurui
# Processing Record 12 of the Set 15 | the valley
# Processing Record 13 of the Set 15 | gondanglegi
# Processing Record 14 of the Set 15 | kisangani
# Processing Record 15 of the Set 15 | lishui
# City not found. Skipping...
# Processing Record 16 of the Set 15 | inirida
# Processing Record 17 of the Set 15 | rio grande
# Processing Record 18 of the Set 15 | bairiki
# Processing Record 19 of the Set 15 | puerto escondido
# Processing Record 20 of the Set 15 | hornepayne
# Processing Record 21 of the Set 15 | vila
# Processing Record 22 of the Set 15 | zhanaozen
# City not found. Skipping...
# Processing Record 23 of the Set 15 | ukiah
# Processing Record 24 of the Set 15 | puerto carreno
# Processing Record 25 of the Set 15 | tonj
# City not found. Skipping...
# Processing Record 26 of the Set 15 | redlands
# Processing Record 27 of the Set 15 | touros
# Processing Record 28 of the Set 15 | mayo
# Processing Record 29 of the Set 15 | kosamba
# Processing Record 30 of the Set 15 | hinton
# Processing Record 31 of the Set 15 | berbera
# Processing Record 32 of the Set 15 | ahuimanu
# Processing Record 33 of the Set 15 | makakilo city
# Processing Record 34 of the Set 15 | zambezi
# Processing Record 35 of the Set 15 | point pedro
# Processing Record 36 of the Set 15 | naze
# Processing Record 37 of the Set 15 | alappuzha
# Processing Record 38 of the Set 15 | nhulunbuy
# Processing Record 39 of the Set 15 | anuradhapura
# Processing Record 40 of the Set 15 | mangrol
# Processing Record 41 of the Set 15 | dauriya
# Processing Record 42 of the Set 15 | los llanos de aridane
# Processing Record 43 of the Set 15 | mbandaka
# Processing Record 44 of the Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 45 of the Set 15 | xinzhi
# City not found. Skipping...
# Processing Record 46 of the Set 15 | soyo
# Processing Record 47 of the Set 15 | westport
# Processing Record 48 of the Set 15 | cape canaveral
# Processing Record 49 of the Set 15 | juneau
# Processing Record 50 of the Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 1 of the Set 16 | clinton
# Processing Record 2 of the Set 16 | nouadhibou
# Processing Record 3 of the Set 16 | blagodatnoye
# Processing Record 4 of the Set 16 | tautira
# Processing Record 5 of the Set 16 | kem
# Processing Record 6 of the Set 16 | chegdomyn
# Processing Record 7 of the Set 16 | lake havasu city
# Processing Record 8 of the Set 16 | balingen
# Processing Record 9 of the Set 16 | cerignola
# Processing Record 10 of the Set 16 | lima
# Processing Record 11 of the Set 16 | kaabong
# Processing Record 12 of the Set 16 | vitim
# Processing Record 13 of the Set 16 | pangkalanbuun
# Processing Record 14 of the Set 16 | skjervoy
# Processing Record 15 of the Set 16 | nioro
# Processing Record 16 of the Set 16 | samsun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 705

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cherskiy      RU  68.7500  161.3000     51.48        54         100
# 1  Saint-Philippe      RE -21.3585   55.7679     67.55        75          40
# 2         Dunedin      NZ -45.8742  170.5036     49.28        82          96
# 3       Tocopilla      CL -22.0920  -70.1979     61.68        70          99
# 4             Bud      US  39.4470  -86.1758     74.01        81           0
#
#    Wind Speed Current Description
# 0       11.39     overcast clouds
# 1       12.01    scattered clouds
# 2        1.92     overcast clouds
# 3        5.37     overcast clouds
# 4        7.34           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
